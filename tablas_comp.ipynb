# %%
import os
import tabula
import pandas as pd

# %%
#Directorio de trabajo
os.chdir("C:/Users/claudio.pacheco/Documents/GitHub/economia/fichas/")
file_path="Ficha_2021.pdf"

# %%
def extract_tables_from_pdf(file_path, page=5):
    # Define areas for each section based on the image
    areas = {
        "Economic Performance": [50, 50, 285, 550],
        "Government Efficiency": [285, 50, 530, 550],
        "Business Efficiency": [530, 50, 680, 550],
        "Infrastructure": [680, 50, 841, 550]
    }

    # Adjust columns for better accuracy based on the image
    column_positions = [150, 300, 450, 600]

    combined_df = pd.DataFrame()

    # Extract tables for each section
    for section, area in areas.items():
        extracted_data = tabula.read_pdf(file_path, pages=page, area=area, columns=column_positions, multiple_tables=True)
        df = pd.concat(extracted_data, ignore_index=True) if isinstance(extracted_data, list) else extracted_data

        # Rename columns based on the required order
        df.columns = ["strengths", "rank_strengths", "weakness", "rank_weak"]
        combined_df = pd.concat([combined_df, df], ignore_index=True)
    def process_dataframe(df):
    # Fill NaN values with empty string
        df.fillna("", inplace=True)
    
    # Combine split strings
        df["strengths"] = df["strengths"] + df["rank_strengths"].str.extract('([a-zA-Z\s]+)', expand=False).fillna('')
        df["weakness"] = df["weakness"] + df["rank_weak"].str.extract('([a-zA-Z\s]+)', expand=False).fillna('')

    # Extract only numeric values for the rank columns
        df["rank_strengths"] = df["rank_strengths"].str.extract('(\d+)', expand=False)
        df["rank_weak"] = df["rank_weak"].str.extract('(\d+)', expand=False)

    # Drop rows which are headers or sub-headers
        mask = (~df["strengths"].str.contains("STRENGTHS", case=False) & 
            ~df["strengths"].str.contains("WEAKNESSES", case=False) & 
            ~df["strengths"].str.isupper())
    
        return df[mask].reset_index(drop=True)
    processed_df = process_dataframe(combined_df)
    
    return processed_df

# %%
extract_tables_from_pdf(file_path)
# Out:
#                                            strengths rank_strengths  \
# 0                    1.4.08  Long-term unemployment              01
# 1                         1.4.07  Unemployment rate              08
# 2              1.4.04  Employment - longterm growth              09
# 3             1.3.13  Relocation threatsof business              10
# 4              1.1.18  Gross fixed capitalformation              11
# 5                        1.4.09  Youth unemployment              12
# 6                      1.2.08  Exports of goods ($bn             13
# 7            1.3.05  Direct investment flows inward              15
# 8                       1.5.02  Cost-of-living index             16
# 9           1.3.07  Direct investment stocks inward              17
# 10                           2.4.01  Tariff barriers             08
# 11        2.2.10  Employee social security tax rate              10
# 12                       2.3.05  Central bank policy             17
# 13              2.2.01  Collected total taxrevenues              18
# 14                     2.2.08  Consumption tax rate              25
# 15                             2.4.14  Start-up days             26
# 16                        2.5.13  Unemployment rate              27
# 17             2.2.02  Collected personalincome tax              28
# 18            2.1.04  Total general government debt              28
# 19                         2.5.15  Disposable income             37
# 20                      3.2.01  Compensation levels              08
# 21                        3.1.08  Large corporations             09
# 22           3.2.15  Labor force - long-term growth              09
# 23                      3.4.11  Women in management              16
# 24                 3.2.24  International experience              25
# 25         3.2.23  Foreign highly skilled personnel              31
# 26           3.5.01  Attitudes toward globalization              33
# 27                                                              NaN
# 28                   4.2.03  Mobile telephone costs              14
# 29  4.1.20  Electricity costs forindustrial clients              19
# 30                          4.1.09  Dependency ratio             19
# 31                        4.2.15  High-tech exports              21
# 32                    4.3.11  Graduates in Sciences              25
# 33         4.2.01  Investment in Telecommunications              27
# 34                          4.4.12  Energy intensity             29
# 35           4.4.17  Exposure to particle pollution              37
#
#                                              weakness rank_weak
# 0             1.2.17  Export concentration by partner        63
# 1          1.2.13  Exports of commercial services (%         59
# 2           1.1.09  Gross fixed capital formation (%)        56
# 3                                  1.5.05  Food costs        52
# 4                        1.1.21  GDP (PPP) per capita        51
# 5                              1.1.20  GDP per capita        50
# 6         1.3.01  Direct investment flows abroad ($bn        49
# 7                             1.4.10  Youth exclusion        47
# 8    1.3.04  Direct investment stocks abroad (%of GDP        47
# 9                        1.2.24  Terms of trade index        45
# 10          2.2.09  Employer social security tax rate        64
# 11                                2.3.14  Rule of law        63
# 12                              2.4.02  Protectionism        63
# 13                    2.4.03  Public sector contracts        62
# 14                               2.3.11  Transparency        62
# 15                            2.4.05  Capital markets        62
# 16                                   2.5.02  Homicide        61
# 17                           2.4.11  Parallel economy        61
# 18                                    2.5.01  Justice        60
# 19                     2.3.13  Bribery and corruption        60
# 20               3.3.04  Access to financial services        63
# 21  3.3.05  Access to financial services - gender ...        60
# 22           3.2.21  Attracting and retaining talents        60
# 23       3.5.06  Digital transformation in companies         59
# 24      3.5.05  Need for economic and social reforms         57
# 25        3.2.18  Foreign labor force - migrant stock        57
# 26                                     3.3.16  Credit        57
# 27                       3.3.14  Shareholders' rights        56
# 28                        4.2.16  ICT service exports        62
# 29            4.3.20  Scientific research legislation        62
# 30     4.2.13  Funding for technological development         62
# 31                         4.4.26  Pollution problems        61
# 32                             4.2.17  Cyber security        61
# 33                         4.4.27  Environmental laws        61
# 34               4.2.09  Digital/Technological skills        61
# 35         4.2.12  Development & application of tech         60

# %%
import pandas as pd
import tabula

def extract_tables_from_pdf(file_path, layout="original", page=5):
    page_width_mm, page_height_mm = 231, 326.8
    mm_to_pt_factor = 72/25.4  # conversion factor from millimeters to points (since PDF uses points as a unit)

    areas_dict = {
        "original": {
            "Economic Performance": [50, 50, 285, 550],
            "Government Efficiency": [285, 50, 530, 550],
            "Business Efficiency": [530, 50, 680, 550],
            "Infrastructure": [680, 50, 841, 550]
        },
        "new": {
            "Economic Performance": [
                20*mm_to_pt_factor, 
                10*mm_to_pt_factor, 
                page_height_mm/2*mm_to_pt_factor, 
                page_width_mm/2*mm_to_pt_factor
            ],
            "Government Efficiency": [
                20*mm_to_pt_factor, 
                page_width_mm/2*mm_to_pt_factor, 
                page_height_mm/2*mm_to_pt_factor, 
                page_width_mm*mm_to_pt_factor
            ],
            "Business Efficiency": [
                page_height_mm/2*mm_to_pt_factor, 
                10*mm_to_pt_factor, 
                page_height_mm*mm_to_pt_factor, 
                page_width_mm/2*mm_to_pt_factor
            ],
            "Infrastructure": [
                page_height_mm/2*mm_to_pt_factor, 
                page_width_mm/2*mm_to_pt_factor, 
                page_height_mm*mm_to_pt_factor, 
                page_width_mm*mm_to_pt_factor
            ]
        }
    }
    areas = areas_dict.get(layout)
    if not areas:
        raise ValueError(f"Invalid layout '{layout}' provided. Choose either 'original' or 'new'.")

    column_positions = [150, 300, 450, 600]
    combined_df = pd.DataFrame()



    for section, area in areas.items():
        extracted_data = tabula.read_pdf(file_path, pages=page, area=area, columns=column_positions, multiple_tables=True)
        df = pd.concat(extracted_data, ignore_index=True) if isinstance(extracted_data, list) else extracted_data
    
        if df.shape[1] == 4:  # If the extracted dataframe has 4 columns
            df.columns = ["strengths", "rank_strengths", "weakness", "rank_weak"]
        elif df.shape[1] == 5:  # If the extracted dataframe has 5 columns
            df.columns = ["strengths", "rank_strengths", "weakness", "rank_weak", "column_5"]
        else:
            raise ValueError(f"Unexpected number of columns in the extracted table: {df.shape[1]}")
    
        combined_df = pd.concat([combined_df, df], ignore_index=True)


    def process_dataframe(df):
        df.fillna("", inplace=True)
        df["strengths"] = df["strengths"] + df["rank_strengths"].str.extract('([a-zA-Z\s]+)', expand=False).fillna('')
        df["weakness"] = df["weakness"] + df["rank_weak"].str.extract('([a-zA-Z\s]+)', expand=False).fillna('')
        df["rank_strengths"] = df["rank_strengths"].str.extract('(\d+)', expand=False)
        df["rank_weak"] = df["rank_weak"].str.extract('(\d+)', expand=False)
        
        mask = (~df["strengths"].str.contains("STRENGTHS", case=False) & 
                ~df["strengths"].str.contains("WEAKNESSES", case=False) & 
                ~df["strengths"].str.isupper())
        
        return df[mask].reset_index(drop=True)

    processed_df = process_dataframe(combined_df)
    return processed_df

# %%
file_path="Ficha_2019.pdf"
fextract_tables_from_pdf(file_path, layout="original",page=5)
# Out:
#                                             strengths rank_strengths  \
# 0                                                                NaN
# 1                               onomic Performance Ra            NaN
# 2                         .08  Long-term unemployment            NaN
# 3                           .02  Cost-of-living index            NaN
# 4                             .09  Youth unemployment            NaN
# 5                              .07  Unemployment rate            NaN
# 6                         .08  Exports of goods ($bn)            NaN
# 7                .05  Direct investment flows inward             NaN
# 8               .07  Direct investment stocks inward             NaN
# 9                                .06  Gasoline prices            NaN
# 10              .03  Direct investment stocks abroad             NaN
# 11                            overnment Efficiency Ra            NaN
# 12  .10  Employee's social security contribution rate            NaN
# 13                  .01  Collected total tax revenues            NaN
# 14                           .05  Central bank policy            NaN
# 15                          .09  Consumption tax rate            NaN
# 16            .07  Effective personal income tax rate            NaN
# 17                             .14  Disposable Income            NaN
# 18                                 .14  Start-up days            NaN
# 19                .04  Total general government debt             NaN
# 20                       .08  Exchange rate stability            NaN
# 21                                                               NaN
# 22                                siness EfficiencyRa            NaN
# 23                           .01  Compensation levels            NaN
# 24                            .08  Large corporations            NaN
# 25                      .23  International experience            NaN
# 26                        .07  Workforce productivity            NaN
# 27                       .04  Credibility of managers            NaN
# 28                                                               NaN
# 29                                                               NaN
# 30                                                               NaN
# 31                        .03  Mobile Telephone costs            NaN
# 32                               .11  Science degrees            NaN
# 33                         .16  High-tech exports (%)            NaN
# 34      .21  Electricity costs for industrial clients            NaN
# 35                           .07  Population - growth            NaN
# 36              .19  Medium- and high-techvalue added            NaN
# 37                                                               NaN
# 38                                                               NaN
# 39                                                               NaN
#
#                                              weakness rank_weak
# 0                                                   M       NaN
# 1                             nk Economic Performance       NaN
# 2            2 1.2.17  Export concentration bypartner       NaN
# 3           8 1.2.13  Exports of commercial services        NaN
# 4                  8 1.5.01  Consumer price inflation       NaN
# 5                     10 1.1.21  GDP (PPP) per capita       NaN
# 6           12 1.1.18  Gross fixed capital formation        NaN
# 7               13 1.1.15  Real GDP growth per capita       NaN
# 8                           16 1.1.20  GDP per capita       NaN
# 9                               17 1.5.05  Food costs       NaN
# 10          28 1.3.13  Relocation threats of business       NaN
# 11                           nk Government Efficiency       NaN
# 12                        10 2.4.11  Parallel economy       NaN
# 13                                12 2.5.02  Homicide       NaN
# 14                       20 2.5.10  Equal opportunity       NaN
# 15                           23 2.4.02  Protectionism       NaN
# 16           25 2.5.04  Risk of political instability       NaN
# 17                  31 2.3.13  Bribery and corruption       NaN
# 18                            32 2.3.11  Transparency       NaN
# 19                                 34 2.5.01  Justice       NaN
# 20                 49 2.4.03  Public sector contracts       NaN
# 21                          2.4.13  Creation of firms       NaN
# 22                             nk Business Efficiency       NaN
# 23                            10 3.5.07  Value system       NaN
# 24               14 3.4.03  Opportunities and threats       NaN
# 25     22 3.5.05  Need for economic andsocial reforms       NaN
# 26           24 3.4.07  Use of big data and analytics       NaN
# 27     29 3.3.07  Regulatory compliance (banking laws       NaN
# 28           3.2.20  Attracting and retaining talents       NaN
# 29      3.1.10  Use of digital tools and technologies       NaN
# 30                      3.4.08  Customer satisfaction       NaN
# 31                     10 4.2.17  ICT service exports       NaN
# 32  13 4.5.06  Pupil-teacher ratio (secondary educ...       NaN
# 33                          17 4.2.18  Cyber security       NaN
# 34  20 4.5.05  Pupil-teacher ratio (primary education       NaN
# 35            27 4.2.10  Digital/Technological skills       NaN
# 36                      30 4.4.26  Pollution problems       NaN
# 37              4.1.14  Quality of air transportation       NaN
# 38                    4.4.25  Sustainable development       NaN
# 39                      4.1.16  Energy infrastructure       NaN

# %%
file_path="Ficha_2019.pdf"
x=tabula.read_pdf(file_path, pages=5)
print(len(x))
x[0]
# Out:
# 1
#                                  Economic Performance  Rank  \
# 0                      1.4.08  Long-term unemployment     2
# 1                        1.5.02  Cost-of-living index     8
# 2                          1.4.09  Youth unemployment     8
# 3                           1.4.07  Unemployment rate    10
# 4                      1.2.08  Exports of goods ($bn)    12
# 5        1.3.05  Direct investment flows inward ($bn)    13
# 6       1.3.07  Direct investment stocks inward ($bn)    16
# 7                             1.5.06  Gasoline prices    17
# 8   1.3.06  Direct investment flows inward (% of GDP)    22
# 9       1.3.03  Direct investment stocks abroad ($bn)    28
# 10                              Government Efficiency  Rank
# 11  2.2.10  Employee's social security contributio...    10
# 12               2.2.01  Collected total tax revenues    12
# 13                        2.3.05  Central bank policy    20
# 14                       2.2.09  Consumption tax rate    23
# 15         2.2.07  Effective personal income tax rate    25
# 16                          2.5.14  Disposable Income    31
# 17                              2.4.14  Start-up days    32
# 18          2.1.04  Total general government debt (%)    34
# 19                    2.3.08  Exchange rate stability    49
# 20                                                NaN   NaN
# 21                                Business Efficiency  Rank
# 22                              3.2.06  Working hours     2
# 23       3.2.03  Remuneration in services professions     5
# 24                        3.2.01  Compensation levels    10
# 25                         3.1.08  Large corporations    14
# 26                   3.2.23  International experience    22
# 27                     3.1.07  Workforce productivity    24
# 28                    3.4.04  Credibility of managers    29
# 29                                                NaN   NaN
# 30                                                NaN   NaN
# 31                                                NaN   NaN
# 32                                     Infrastructure  Rank
# 33                     4.2.03  Mobile Telephone costs    10
# 34                            4.3.11  Science degrees    13
# 35                      4.2.16  High-tech exports (%)    17
# 36   4.1.21  Electricity costs for industrial clients    20
# 37                        4.1.07  Population - growth    27
# 38          4.3.19  Medium- and high-tech value added    30
# 39                                                NaN   NaN
# 40                                                NaN   NaN
# 41                                                NaN   NaN
# 42                                                NaN   NaN
#
#                                Economic Performance.1 Rank.1
# 0             1.2.17  Export concentration by partner     62
# 1          1.2.13  Exports of commercial services (%)     59
# 2                    1.5.01  Consumer price inflation     56
# 3                        1.1.21  GDP (PPP) per capita     50
# 4   1.1.18  Gross fixed capital formation - real g...     50
# 5                  1.1.15  Real GDP growth per capita     49
# 6                              1.1.20  GDP per capita     47
# 7                                  1.5.05  Food costs     47
# 8                              1.4.02  Employment (%)     46
# 9              1.3.13  Relocation threats of business     46
# 10                              Government Efficiency   Rank
# 11                           2.4.11  Parallel economy     60
# 12                                   2.5.02  Homicide     59
# 13                          2.5.10  Equal opportunity     59
# 14                              2.4.02  Protectionism     58
# 15              2.5.04  Risk of political instability     58
# 16                     2.3.13  Bribery and corruption     57
# 17                               2.3.11  Transparency     56
# 18                                    2.5.01  Justice     55
# 19                    2.4.03  Public sector contracts     55
# 20                          2.4.13  Creation of firms     54
# 21                                Business Efficiency   Rank
# 22        3.5.06  Digital transformation in companies     61
# 23                      3.3.01  Banking sector assets     59
# 24                               3.5.07  Value system     58
# 25                  3.4.03  Opportunities and threats     58
# 26       3.5.05  Need for economic and social reforms     57
# 27              3.4.07  Use of big data and analytics     56
# 28       3.3.07  Regulatory compliance (banking laws)     55
# 29           3.2.20  Attracting and retaining talents     54
# 30      3.1.10  Use of digital tools and technologies     54
# 31                      3.4.08  Customer satisfaction     54
# 32                                     Infrastructure   Rank
# 33                        4.2.17  ICT service exports     62
# 34  4.5.06  Pupil-teacher ratio (secondary education)     61
# 35                             4.2.18  Cyber security     59
# 36    4.5.05  Pupil-teacher ratio (primary education)     58
# 37               4.2.10  Digital/Technological skills     58
# 38                         4.4.26  Pollution problems     58
# 39              4.1.14  Quality of air transportation     58
# 40                    4.4.25  Sustainable development     58
# 41                      4.1.16  Energy infrastructure     58
# 42                  4.2.04  Communications technology     58
